# %% [markdown]
# ### Camera math  - 2022 0128 CJH
# ---
# * use this math once cv has told you where the bounding box of your contour is - see opencv_segmentation notebook
#   * open an image
#   * blur if necessary
#   * HSV threshold
#   * find contours
#   * run `cv2.boundingRect(contour)` to get the x,y,w,h used below
# * if you don't have it, get opencv with `pip install opencv-python`

# %%
# import cv2

# %% [markdown]
# ### top down view, figuring our distance from camera to object

# %% [markdown]
# ![image.png](attachment:9f7c8391-b8fc-4196-a60a-2bd15e5d042b.png)

# %% [markdown]
# ### looking at the image, figuring out the angle to rotate to center on the object

# %% [markdown]
# ![image.png](attachment:cc4a035c-af5e-464a-9c9b-b91d086d2973.png)
