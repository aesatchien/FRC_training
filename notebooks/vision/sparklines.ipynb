# %%
## Communicating directly with the br-EFB via wireless
### 9/3/2018 CJH for LCToRFA

# %%
import brEFB_CJH as brefb
from importlib import reload
import time
import pandas as pd
import holoviews as hv
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 5
#       3 import time
#       4 import pandas as pd
# ----> 5 import holoviews as hv
#       6 import matplotlib.pyplot as plt
#       7 import numpy as np
#
# File ~\Miniconda3\lib\site-packages\holoviews\__init__.py:85
#      81 __version__ = str(param.version.Version(fpath=__file__, archive_commit="$Format:%h$",
#      82                                         reponame="holoviews"))
#      84 from . import util                                       # noqa (API import)
# ---> 85 from .annotators import annotate                         # noqa (API import)
#      86 from .core import archive, config                        # noqa (API import)
#      87 from .core.boundingregion import BoundingBox             # noqa (API import)
#
# File ~\Miniconda3\lib\site-packages\holoviews\annotators.py:8
# ...

# %%
reload(brefb)
# Out:
# <module 'brEFB_CJH' from 'C:\\CJH\\Python\\LCTRFA\\float_git\\lcf_float\\python\\brEFB_CJH.py'>

# %%
brefb.set_banks()
# Out:
# Searching for banks...  found dmx 6 at ip 200...  found dmx 10 at ip 201...
# Set bank a to 200 and bank b to 201

# %% [markdown]
# ### Read PID values

# %%
confa = brefb.get_conf_df('a')
brefb.style_df(confa,'a')
# Out:
# <style type="text/css">
# #T_412a9 caption {
#   text-align: left;
#   font-size: 150%;
#   color: black;
# }
# </style>
# <table id="T_412a9">
#   <caption> - Bank A -</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_412a9_level0_col0" class="col_heading level0 col0" >proportional_gain</th>
#       <th id="T_412a9_level0_col1" class="col_heading level0 col1" >integral_gain</th>
#       <th id="T_412a9_level0_col2" class="col_heading level0 col2" >derivative_gain</th>
#       <th id="T_412a9_level0_col3" class="col_heading level0 col3" >reversed</th>
#       <th id="T_412a9_level0_col4" class="col_heading level0 col4" >scaled_min</th>
#       <th id="T_412a9_level0_col5" class="col_heading level0 col5" >scaled_max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_412a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_412a9_row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
confb = brefb.get_conf_df('b')
brefb.style_df(confb,'b')
# Out:
# <style type="text/css">
# #T_9b0d0 caption {
#   text-align: left;
#   font-size: 150%;
#   color: black;
# }
# </style>
# <table id="T_9b0d0">
#   <caption> - Bank B -</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b0d0_level0_col0" class="col_heading level0 col0" >proportional_gain</th>
#       <th id="T_9b0d0_level0_col1" class="col_heading level0 col1" >integral_gain</th>
#       <th id="T_9b0d0_level0_col2" class="col_heading level0 col2" >derivative_gain</th>
#       <th id="T_9b0d0_level0_col3" class="col_heading level0 col3" >reversed</th>
#       <th id="T_9b0d0_level0_col4" class="col_heading level0 col4" >scaled_min</th>
#       <th id="T_9b0d0_level0_col5" class="col_heading level0 col5" >scaled_max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b0d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b0d0_row0_col0" class="data row0 col0" >2.500000</td>
# ...

# %%
shows = brefb.get_shows_df('a')
shows
# Out:
#                         name  length  frame_rate steppable  end_action
# 0  La Canada-Flintridge 2019   13050          30       Yes  Do Nothing

# %% [markdown]
# ### Get transducer / setpoint states

# %%
state_a = brefb.current_state_df('a')
state_a
# Out:
#    axis  transducer 01  transducer 256  setpoint 01  setpoint sp256
# 0     0          0.132              33        0.044              11
# 1     1          0.509             130        0.024               6
# 2     2          0.849             217        0.011               2
# 3     3          0.054              13        0.004               1

# %%
state_b = brefb.current_state_df('b')
state_b
# Out:
#    axis  transducer 01  transducer 256  setpoint 01  setpoint sp256
# 0     0          0.526             134        0.137              35
# 1     1          0.004               1        0.079              20
# 2     2          0.004               0        0.125              32
# 3     3          0.004               1        0.071              18

# %%
# make a df to show in the console for tuning - 20221030 
temp_a = pd.concat([state_a, confa], axis=1)
temp_b = pd.concat([state_b, confb], axis=1)
temp_a['axis'] = 'A' + temp_a['axis'].astype(str)
temp_b['axis'] = 'B' + temp_b['axis'].astype(str)
console_df = pd.concat([temp_a, temp_b])
console_df.columns = ['axis', 'td dec', 'td 256', 'sp dec', 'sp 256', 'P gain', 'I gain', 'D gain', 'rev', 'td min', 'td max']
console_df
# Out:
#   axis  td dec  td 256  sp dec  sp 256  P gain  I gain  D gain    rev  td min  \
# 0   A0   0.132      33   0.044      11     1.0     0.2       0  False      10
# 1   A1   0.509     130   0.024       6     1.9     0.0       0  False       5
# 2   A2   0.849     217   0.011       2     3.0     0.1       0  False       2
# 3   A3   0.054      13   0.004       1     2.0     0.1       0  False       0
# 0   B0   0.526     134   0.137      35     2.5     0.1       0  False      35
# 1   B1   0.004       1   0.079      20     2.0     0.2       0  False      20
# 2   B2   0.004       0   0.125      32     2.0     0.1       0  False      32
# 3   B3   0.004       1   0.071      18     3.5     0.0       0  False      18
#
#    td max
# 0     160
# 1     180
# 2     160
# 3     255
# 0     200
# 1     245
# 2     230
# 3     244

# %%
None in [7,0,None,1]
# Out:
# True

# %%
import pickle

# %%
# let me use this df to test a console app
with open('console.pkl', 'wb') as f:
    pickle.dump(console_df, f)

# %%
import datetime
today = datetime.datetime.now().strftime('%m/%d/%Y %H:%M:%S')
today
# Out:
# '10/30/2022 16:24:13'

# %% [markdown]
# ### Make some plots

# %%
df_a, label_a = brefb.prepare_all_telemetry(end_time=40, dt=.1, axes=[0,1,2,3], bank='a')
brefb.create_matplot(df_a,label_a, bank='a')
# Out:
#  Progress: [##########] 100.0%  0:▁▁▁▁▁▁▁▁ 1:▁▁▁▁▁▁▁▁ 2:▁▁▁▁▁▁▁▁ 3:▁▁▁▁▁▁▁▁

# %%
df_b, label_b = brefb.prepare_all_telemetry(end_time=30, dt=.1, axes=[0,1,2,3], bank='b')
brefb.create_matplot(df_b,label_b,save=False, bank='b')
# Out:
#  Progress: [##########] 100.0%  0:▆▆▆▆▅▅▅▅ 1:▇▇▇▆▆▆▆▅ 2:▆▆▆▆▆▆▆▆ 3:▃▃▃▃▃▂▂▂

# %%
brefb.create_matplot(df=df_b,label=label_b, axes=[0,1,2,3], save=True, fname='./pngs/LCF_BankB_AnimationTest_All_SPs_20191220.png')

# %%
brefb.create_matplot(df=df_a,label=label_a.replace('Bank B', 'Bank A'), axes=[1,2], save=False, bank='a', fname='./pngs/LCF_BankA_AnimationTest_Guitars_20191220.png')

# %%
brefb.create_matplot(df_a,label,save=True,fname='LCF_BankA_AnimationTest_20191128.png')

# %% [markdown]
# ### Playing around

# %%
reload(brefb)
brefb.set_banks()
# Out:
# Searching for banks...  found dmx 10 at ip 200...  found dmx 6 at ip 201...
# Set bank a to 201 and bank b to 200

# %%
import numpy as np

# %%
# -*- coding: utf-8 -*-
# Unicode: 9601, 9602, 9603, 9604, 9605, 9606, 9607, 9608
bar = '▁▂▃▄▅▆▇█'
bar = '▁▂▃▅▆▇'
barcount = len(bar)
 
def sparkline(numbers, autoscale=True):
    if autoscale:
        mn, mx = np.min(numbers), np.max(numbers)
    else:
        mn, mx = -1.0, 1.0
    extent = mx - mn
    sparkline = ''.join(bar[min([barcount - 1,int((n - mn) / extent * barcount)])] for n in numbers)
    return mn, mx, sparkline

# %%
max = 5
b= list((np.linspace(-1,1, 20))**2)
for i in range(max):
    #a=np.random.randint(10, size=10)
    #a=np.random.normal(1, 1, 10)
    a=np.cos(np.linspace(-np.pi-(3*i/max)*np.pi, np.pi-(3*i/max)*np.pi, 20))
    b.insert(0, b.pop())
    mn, mx, spark = sparkline(a)
    mn2, mx2, sparkb = sparkline(b)
    print(f'\r{spark}\t{sparkb}' ,end='',flush=True)
    time.sleep(0.1)
# Out:
# ▃▂▁▁▁▁▁▂▃▅▆▇▇▇▇▇▆▆▅▃	▃▃▅▆▇▇▆▅▃▃▂▁▁▁▁▁▁▁▁▂

# %%
max = 30
for i in range(max):
    #a=np.random.randint(10, size=10)
    #a=np.random.normal(1, 1, 10)
    a=[np.sin(i),np.sin(np.pi/4+i),np.sin(np.pi/2+i),np.sin(3*np.pi/4+i)]
    mn, mx, spark = sparkline(a,autoscale=False)
    print("\r",spark,end="",flush=True)
    time.sleep(0.12)
# Out:
#  ▂▁▁▃

# %%
bank = 'b'
target = 'command'
result, url = brefb.get_url(bank, target)
print(f'Result: {result} and url: {url}')
# Out:
# Bank b not connected
# Result: -1 and url:

# %%
brefb.update_sparks()
text = "\nTD: " + brefb.sparkline(brefb.sparks['a'][::2],False) +"\nSP: "+brefb.sparkline(brefb.sparks['a'][1::2],False)
print(text)
# Out:
# TD: ▇▆▅▅
# SP: ▅▅▆▇

# %%
df_a['t'].diff().describe()
# Out:
# count    250.000000
# mean       0.159529
# std        0.025249
# min        0.150988
# 25%        0.153503
# 50%        0.154968
# 75%        0.158275
# max        0.485974
# Name: t, dtype: float64
